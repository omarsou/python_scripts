# %%
import sys 
import matplotlib.pyplot as plt
sys.path.insert(0, '..')
from maskrcnn_crop_generator.crop_generator import ImageDetectorCrop

# %%
gen = ImageDetectorCrop()
ls = gen.crop_image('birds.jpg', ['bird'], threshold=0.7)
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /Users/omarsouaidi/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# ...

# %%
plt.imshow(ls['bird'][0])

# %%
plt.imshow(ls['bird'][1])

# %% [markdown]
# We also could have resize them, let's see

# %%
gen = ImageDetectorCrop(resize=True, size=(500,500))
ls = gen.crop_image('birds.jpg', ['bird'], threshold=0.7)

# %%
plt.imshow(ls['bird'][0])

# %%
plt.imshow(ls['bird'][1])
